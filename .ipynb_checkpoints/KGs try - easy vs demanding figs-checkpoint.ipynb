# %%
# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
# Read in the raw data
raw_data = pd.read_excel('Simulated Caregiving - Easy v Demanding.xlsx', sheet_name=None)
data = raw_data.copy()

# Merge all the sheets into a single dataframe and add sheet name as the "sessionæ variable
all_data = pd.DataFrame()
for k in data.keys():
    temp_df = data.get(k)
    temp_df['session'] = k
    all_data = pd.concat([all_data, temp_df])

# Relabel the cols for easier handling
all_data.columns = ['items', 'condition', 'interval_number', 'percent_interval_w_care', 'session']
    
# Reorganize the cols logically
all_data = all_data[[
    'session', 'items', 'condition', 'interval_number', 'percent_interval_w_care'
]].reset_index(drop=True)

all_data
# Out:
#        session items  condition  interval_number  percent_interval_w_care
# 0     SP2018-1   Yes       Easy                1                       95
# 1     SP2018-1   Yes       Easy                2                        5
# 2     SP2018-1   Yes       Easy                3                       85
# 3     SP2018-1   Yes       Easy                4                       20
# 4     SP2018-1   Yes       Easy                5                       70
# 5     SP2018-1   Yes       Easy                6                       35
# 6     SP2018-1   Yes  Demanding                7                       35
# 7     SP2018-1   Yes  Demanding                8                       30
# 8     SP2018-1   Yes  Demanding                9                       15
# 9     SP2018-1   Yes  Demanding               10                       30
# 10    SP2018-1   Yes  Demanding               11                       30
# 11    SP2018-1   Yes  Demanding               12                       20
# 12    SP2018-1   Yes       Easy               13                       15
# 13    SP2018-1   Yes       Easy               14                       15
# 14    SP2018-1   Yes       Easy               15                       20
# 15    SP2018-1   Yes       Easy               16                       15
# 16    SP2018-1   Yes       Easy               17                       15
# 17    SP2018-1   Yes       Easy               18                       15
# 18    SP2018-1   Yes  Demanding               19                       35
# 19    SP2018-1   Yes  Demanding               20                       25
# 20    SP2018-1   Yes  Demanding               21                       20
# 21    SP2018-1   Yes  Demanding               22                       35
# 22    SP2018-1   Yes  Demanding               23                       20
# 23    SP2018-1   Yes  Demanding               24                       30
# 24    SP2018-2   Yes       Easy                1                       20
# 25    SP2018-2   Yes       Easy                2                       20
# 26    SP2018-2   Yes       Easy                3                       20
# 27    SP2018-2   Yes       Easy                4                       20
# 28    SP2018-2   Yes       Easy                5                       15
# 29    SP2018-2   Yes       Easy                6                       20
# 30    SP2018-2   Yes  Demanding                7                       60
# 31    SP2018-2   Yes  Demanding                8                       55
# 32    SP2018-2   Yes  Demanding                9                       45
# 33    SP2018-2   Yes  Demanding               10                       50
# 34    SP2018-2   Yes  Demanding               11                       55
# 35    SP2018-2   Yes  Demanding               12                       50
# 36    SP2018-2   Yes       Easy               13                       15
# 37    SP2018-2   Yes       Easy               14                       15
# 38    SP2018-2   Yes       Easy               15                       15
# 39    SP2018-2   Yes       Easy               16                       15
# 40    SP2018-2   Yes       Easy               17                       15
# 41    SP2018-2   Yes       Easy               18                       15
# 42    SP2018-2   Yes  Demanding               19                       50
# 43    SP2018-2   Yes  Demanding               20                       60
# 44    SP2018-2   Yes  Demanding               21                       50
# 45    SP2018-2   Yes  Demanding               22                       65
# 46    SP2018-2   Yes  Demanding               23                       55
# 47    SP2018-2   Yes  Demanding               24                       55
# 48    SP2018-3   Yes       Easy                1                       15
# 49    SP2018-3   Yes       Easy                2                       15
# 50    SP2018-3   Yes       Easy                3                       10
# 51    SP2018-3   Yes       Easy                4                       20
# 52    SP2018-3   Yes       Easy                5                       15
# 53    SP2018-3   Yes       Easy                6                       25
# 54    SP2018-3   Yes  Demanding                7                       75
# 55    SP2018-3   Yes  Demanding                8                       65
# 56    SP2018-3   Yes  Demanding                9                       60
# 57    SP2018-3   Yes  Demanding               10                       40
# 58    SP2018-3   Yes  Demanding               11                       80
# 59    SP2018-3   Yes  Demanding               12                       40
# 60    SP2018-3   Yes       Easy               13                       20
# 61    SP2018-3   Yes       Easy               14                       20
# 62    SP2018-3   Yes       Easy               15                       20
# 63    SP2018-3   Yes       Easy               16                       20
# 64    SP2018-3   Yes       Easy               17                       10
# 65    SP2018-3   Yes       Easy               18                       10
# 66    SP2018-3   Yes  Demanding               19                       65
# 67    SP2018-3   Yes  Demanding               20                       20
# 68    SP2018-3   Yes  Demanding               21                       45
# 69    SP2018-3   Yes  Demanding               22                       40
# 70    SP2018-3   Yes  Demanding               23                       40
# 71    SP2018-3   Yes  Demanding               24                       35
# 72    SP2018-4   Yes       Easy                1                       25
# 73    SP2018-4   Yes       Easy                2                       10
# 74    SP2018-4   Yes       Easy                3                       15
# 75    SP2018-4   Yes       Easy                4                       15
# 76    SP2018-4   Yes       Easy                5                       15
# 77    SP2018-4   Yes       Easy                6                       15
# 78    SP2018-4   Yes  Demanding                7                       50
# 79    SP2018-4   Yes  Demanding                8                       55
# 80    SP2018-4   Yes  Demanding                9                       75
# 81    SP2018-4   Yes  Demanding               10                       80
# 82    SP2018-4   Yes  Demanding               11                       80
# 83    SP2018-4   Yes  Demanding               12                       65
# 84    SP2018-4   Yes       Easy               13                       20
# 85    SP2018-4   Yes       Easy               14                       20
# 86    SP2018-4   Yes       Easy               15                       15
# 87    SP2018-4   Yes       Easy               16                       10
# 88    SP2018-4   Yes       Easy               17                       15
# 89    SP2018-4   Yes       Easy               18                       10
# 90    SP2018-4   Yes  Demanding               19                       45
# 91    SP2018-4   Yes  Demanding               20                       95
# 92    SP2018-4   Yes  Demanding               21                       90
# 93    SP2018-4   Yes  Demanding               22                      100
# 94    SP2018-4   Yes  Demanding               23                      100
# 95    SP2018-4   Yes  Demanding               24                       90
# 96    FA2018-1    No       Easy                1                       80
# 97    FA2018-1    No       Easy                2                       90
# 98    FA2018-1    No       Easy                3                      100
# 99    FA2018-1    No       Easy                4                       90
# 100   FA2018-1    No       Easy                5                       95
# 101   FA2018-1    No       Easy                6                       90
# 102   FA2018-1    No  Demanding                7                       85
# 103   FA2018-1    No  Demanding                8                       65
# 104   FA2018-1    No  Demanding                9                       75
# 105   FA2018-1    No  Demanding               10                       75
# 106   FA2018-1    No  Demanding               11                       75
# 107   FA2018-1    No  Demanding               12                       65
# 108   FA2018-1    No       Easy               13                       55
# 109   FA2018-1    No       Easy               14                       35
# 110   FA2018-1    No       Easy               15                       20
# 111   FA2018-1    No       Easy               16                       25
# 112   FA2018-1    No       Easy               17                       20
# 113   FA2018-1    No       Easy               18                       25
# 114   FA2018-1    No  Demanding               19                       55
# 115   FA2018-1    No  Demanding               20                       95
# 116   FA2018-1    No  Demanding               21                       85
# 117   FA2018-1    No  Demanding               22                       75
# 118   FA2018-1    No  Demanding               23                       65
# 119   FA2018-1    No  Demanding               24                       60
# 120   FA2018-1    No       Easy               25                       15
# 121   FA2018-1    No       Easy               26                       15
# 122   FA2018-1    No       Easy               27                       15
# 123   FA2018-3    No       Easy                1                       15
# 124   FA2018-3    No       Easy                2                       20
# 125   FA2018-3    No       Easy                3                       25
# 126   FA2018-3    No       Easy                4                       25
# 127   FA2018-3    No       Easy                5                       20
# 128   FA2018-3    No       Easy                6                       25
# 129   FA2018-3    No  Demanding                7                       40
# 130   FA2018-3    No  Demanding                8                       55
# 131   FA2018-3    No  Demanding                9                       55
# 132   FA2018-3    No  Demanding               10                       55
# 133   FA2018-3    No  Demanding               11                       55
# 134   FA2018-3    No  Demanding               12                       50
# 135   FA2018-3    No       Easy               13                       10
# 136   FA2018-3    No       Easy               14                       25
# 137   FA2018-3    No       Easy               15                       20
# 138   FA2018-3    No       Easy               16                       30
# 139   FA2018-3    No       Easy               17                       15
# 140   FA2018-3    No       Easy               18                       15
# 141   FA2018-3    No  Demanding               19                       55
# 142   FA2018-3    No  Demanding               20                       70
# 143   FA2018-3    No  Demanding               21                       60
# 144   FA2018-3    No  Demanding               22                       40
# 145   FA2018-3    No  Demanding               23                       60
# 146   FA2018-3    No  Demanding               24                       75
# 147   FA2018-4    No       Easy                1                       25
# 148   FA2018-4    No       Easy                2                       30
# 149   FA2018-4    No       Easy                3                       35
# 150   FA2018-4    No       Easy                4                       25
# 151   FA2018-4    No       Easy                5                       20
# 152   FA2018-4    No       Easy                6                       30
# 153   FA2018-4    No  Demanding                7                       55
# 154   FA2018-4    No  Demanding                8                       60
# 155   FA2018-4    No  Demanding                9                       60
# 156   FA2018-4    No  Demanding               10                       40
# 157   FA2018-4    No  Demanding               11                       45
# 158   FA2018-4    No  Demanding               12                       40
# 159   FA2018-4    No       Easy               13                       10
# 160   FA2018-4    No       Easy               14                       10
# 161   FA2018-4    No       Easy               15                       15
# 162   FA2018-4    No       Easy               16                        0
# 163   FA2018-4    No       Easy               17                       35
# 164   FA2018-4    No       Easy               18                       10
# 165   FA2018-4    No  Demanding               19                       50
# 166   FA2018-4    No  Demanding               20                       40
# 167   FA2018-4    No  Demanding               21                       20
# 168   FA2018-4    No  Demanding               22                       45
# 169   FA2018-4    No  Demanding               23                       15
# 170   FA2018-4    No  Demanding               24                       30
# 171   FA2018-5    No       Easy                1                       45
# 172   FA2018-5    No       Easy                2                       60
# 173   FA2018-5    No       Easy                3                       40
# 174   FA2018-5    No       Easy                4                       35
# 175   FA2018-5    No       Easy                5                       45
# 176   FA2018-5    No       Easy                6                       15
# 177   FA2018-5    No  Demanding                7                       60
# 178   FA2018-5    No  Demanding                8                       75
# 179   FA2018-5    No  Demanding                9                       65
# 180   FA2018-5    No  Demanding               10                       70
# 181   FA2018-5    No  Demanding               11                       80
# 182   FA2018-5    No  Demanding               12                       55
# 183   FA2018-5    No       Easy               13                       15
# 184   FA2018-5    No       Easy               14                       20
# 185   FA2018-5    No       Easy               15                       15
# 186   FA2018-5    No       Easy               16                       20
# 187   FA2018-5    No       Easy               17                       50
# 188   FA2018-5    No       Easy               18                       30
# 189   FA2018-5    No  Demanding               19                       70
# 190   FA2018-5    No  Demanding               20                       60
# 191   FA2018-5    No  Demanding               21                       65
# 192   FA2018-5    No  Demanding               22                       65
# 193   FA2018-5    No       Easy               23                       20
# 194   FA2018-5    No       Easy               24                       20
# 195   FA2018-5    No       Easy               25                       20
# 196   FA2018-6    No       Easy                1                       95
# 197   FA2018-6    No       Easy                2                       90
# 198   FA2018-6    No       Easy                3                      100
# 199   FA2018-6    No       Easy                4                       90
# 200   FA2018-6    No       Easy                5                       95
# 201   FA2018-6    No       Easy                6                       95
# 202   FA2018-6    No  Demanding                7                       90
# 203   FA2018-6    No  Demanding                8                       85
# 204   FA2018-6    No  Demanding                9                       70
# 205   FA2018-6    No  Demanding               10                       70
# 206   FA2018-6    No  Demanding               11                       60
# 207   FA2018-6    No  Demanding               12                       75
# 208   FA2018-6    No       Easy               13                       30
# 209   FA2018-6    No       Easy               14                       40
# 210   FA2018-6    No       Easy               15                       50
# 211   FA2018-6    No       Easy               16                       55
# 212   FA2018-6    No       Easy               17                       50
# 213   FA2018-6    No       Easy               18                       75
# 214   FA2018-6    No  Demanding               19                       90
# 215   FA2018-6    No  Demanding               20                       60
# 216   FA2018-6    No  Demanding               21                       75
# 217   FA2018-6    No  Demanding               22                       65
# 218   FA2018-6    No  Demanding               23                       50
# 219   FA2018-6    No  Demanding               24                       70
# 220   FA2018-7    No       Easy                1                       85
# 221   FA2018-7    No       Easy                2                       80
# 222   FA2018-7    No       Easy                3                       55
# 223   FA2018-7    No       Easy                4                       80
# 224   FA2018-7    No       Easy                5                       75
# 225   FA2018-7    No       Easy                6                       75
# 226   FA2018-7    No  Demanding                7                       95
# 227   FA2018-7    No  Demanding                8                       95
# 228   FA2018-7    No  Demanding                9                       85
# 229   FA2018-7    No  Demanding               10                       85
# 230   FA2018-7    No  Demanding               11                       60
# 231   FA2018-7    No  Demanding               12                       95
# 232   FA2018-7    No       Easy               13                       65
# 233   FA2018-7    No       Easy               14                       20
# 234   FA2018-7    No       Easy               15                       75
# 235   FA2018-7    No       Easy               16                       60
# 236   FA2018-7    No       Easy               17                       25
# 237   FA2018-7    No       Easy               18                       25
# 238   FA2018-7    No  Demanding               19                       75
# 239   FA2018-7    No  Demanding               20                       65
# 240   FA2018-7    No  Demanding               21                       30
# 241   FA2018-7    No  Demanding               22                       35
# 242   FA2018-7    No  Demanding               23                       10
# 243   FA2018-7    No  Demanding               24                        5
# 244   FA2018-8   Yes       Easy                1                       60
# 245   FA2018-8   Yes       Easy                2                       85
# 246   FA2018-8   Yes       Easy                3                       85
# 247   FA2018-8   Yes       Easy                4                       60
# 248   FA2018-8   Yes       Easy                5                       50
# 249   FA2018-8   Yes       Easy                6                       50
# 250   FA2018-8   Yes  Demanding                7                       60
# 251   FA2018-8   Yes  Demanding                8                       30
# 252   FA2018-8   Yes  Demanding                9                       45
# 253   FA2018-8   Yes  Demanding               10                       45
# 254   FA2018-8   Yes  Demanding               11                       95
# 255   FA2018-8   Yes  Demanding               12                       80
# 256   FA2018-8   Yes       Easy               13                      100
# 257   FA2018-8   Yes       Easy               14                       80
# 258   FA2018-8   Yes       Easy               15                       45
# 259   FA2018-8   Yes       Easy               16                       10
# 260   FA2018-8   Yes       Easy               17                       20
# 261   FA2018-8   Yes       Easy               18                       10
# 262   FA2018-8   Yes  Demanding               19                       85
# 263   FA2018-8   Yes  Demanding               20                       60
# 264   FA2018-8   Yes  Demanding               21                       50
# 265   FA2018-8   Yes  Demanding               22                       35
# 266   FA2018-8   Yes  Demanding               23                       95
# 267   FA2018-8   Yes  Demanding               24                      100
# 268   FA2018-9   Yes       Easy                1                       15
# 269   FA2018-9   Yes       Easy                2                       15
# 270   FA2018-9   Yes       Easy                3                       15
# 271   FA2018-9   Yes       Easy                4                       20
# 272   FA2018-9   Yes       Easy                5                       20
# 273   FA2018-9   Yes       Easy                6                       15
# 274   FA2018-9   Yes  Demanding                7                       55
# 275   FA2018-9   Yes  Demanding                8                       70
# 276   FA2018-9   Yes  Demanding                9                       75
# 277   FA2018-9   Yes  Demanding               10                       75
# 278   FA2018-9   Yes  Demanding               11                       85
# 279   FA2018-9   Yes  Demanding               12                       80
# 280   FA2018-9   Yes       Easy               13                       30
# 281   FA2018-9   Yes       Easy               14                       15
# 282   FA2018-9   Yes       Easy               15                       15
# 283   FA2018-9   Yes       Easy               16                       15
# 284   FA2018-9   Yes  Demanding               17                       80
# 285   FA2018-9   Yes  Demanding               18                       90
# 286   FA2018-9   Yes  Demanding               19                       95
# 287   FA2018-9   Yes  Demanding               20                       85
# 288  FA2018-10   Yes       Easy                1                       15
# 289  FA2018-10   Yes       Easy                2                       20
# 290  FA2018-10   Yes       Easy                3                       20
# 291  FA2018-10   Yes       Easy                4                       20
# 292  FA2018-10   Yes       Easy                5                       15
# 293  FA2018-10   Yes       Easy                6                       15
# 294  FA2018-10   Yes  Demanding                7                       65
# 295  FA2018-10   Yes  Demanding                8                       60
# 296  FA2018-10   Yes  Demanding                9                       65
# 297  FA2018-10   Yes  Demanding               10                       70
# 298  FA2018-10   Yes  Demanding               11                       70
# 299  FA2018-10   Yes  Demanding               12                       70
# 300  FA2018-10   Yes       Easy               13                       20
# 301  FA2018-10   Yes       Easy               14                       20
# 302  FA2018-10   Yes       Easy               15                       20
# 303  FA2018-10   Yes  Demanding               16                       70
# 304  FA2018-10   Yes  Demanding               17                       65
# 305  FA2018-10   Yes  Demanding               18                       65
# 306  FA2018-10   Yes  Demanding               19                       65
# 307  FA2018-11   Yes       Easy                1                       20
# 308  FA2018-11   Yes       Easy                2                       15
# 309  FA2018-11   Yes       Easy                3                       15
# 310  FA2018-11   Yes       Easy                4                       15
# 311  FA2018-11   Yes       Easy                5                       15
# 312  FA2018-11   Yes       Easy                6                       15
# 313  FA2018-11   Yes  Demanding                7                       40
# 314  FA2018-11   Yes  Demanding                8                       60
# 315  FA2018-11   Yes  Demanding                9                       55
# 316  FA2018-11   Yes  Demanding               10                       95
# 317  FA2018-11   Yes  Demanding               11                       30
# 318  FA2018-11   Yes  Demanding               12                       30
# 319  FA2018-11   Yes       Easy               13                        5
# 320  FA2018-11   Yes       Easy               14                        5
# 321  FA2018-11   Yes       Easy               15                       50
# 322  FA2018-11   Yes       Easy               16                        5
# 323  FA2018-11   Yes       Easy               17                        0
# 324  FA2018-11   Yes       Easy               18                       10
# 325  FA2018-11   Yes  Demanding               19                       70
# 326  FA2018-11   Yes  Demanding               20                       30
# 327  FA2018-11   Yes  Demanding               21                       65
# 328  FA2018-11   Yes  Demanding               22                       40
# 329  FA2018-11   Yes  Demanding               23                       65
# 330  FA2018-11   Yes  Demanding               24                       55
# 331  FA2018-12   Yes       Easy                1                       20
# 332  FA2018-12   Yes       Easy                2                       15
# 333  FA2018-12   Yes       Easy                3                       20
# 334  FA2018-12   Yes       Easy                4                       15
# 335  FA2018-12   Yes  Demanding                5                       50
# 336  FA2018-12   Yes  Demanding                6                       55
# 337  FA2018-12   Yes  Demanding                7                       50
# 338  FA2018-12   Yes  Demanding                8                       50
# 339  FA2018-12   Yes       Easy                9                       15
# 340  FA2018-12   Yes       Easy               10                       15
# 341  FA2018-12   Yes       Easy               11                       10
# 342  FA2018-12   Yes  Demanding               12                       50
# 343  FA2018-12   Yes  Demanding               13                       45
# 344  FA2018-12   Yes  Demanding               14                       50
# 345  FA2018-13   Yes       Easy                1                       20
# 346  FA2018-13   Yes       Easy                2                       15
# 347  FA2018-13   Yes       Easy                3                       15
# 348  FA2018-13   Yes       Easy                4                       15
# 349  FA2018-13   Yes  Demanding                5                       50
# 350  FA2018-13   Yes  Demanding                6                       55
# 351  FA2018-13   Yes  Demanding                7                       65
# 352  FA2018-13   Yes  Demanding                8                       55
# 353  FA2018-13   Yes  Demanding                9                       55
# 354  FA2018-13   Yes  Demanding               10                       45
# 355  FA2018-13   Yes       Easy               11                       15
# 356  FA2018-13   Yes       Easy               12                       15
# 357  FA2018-13   Yes       Easy               13                       15
# 358  FA2018-13   Yes  Demanding               14                       70
# 359  FA2018-13   Yes  Demanding               15                       65
# 360  FA2018-13   Yes  Demanding               16                       70

# %%
# Question for David: Was this step necessary after I took out the concurrent dataset???? 

# Merge the easy and demanding cols into the percent_interval_w_care col

# Modify missing vals so we can do the math
all_data = all_data.fillna(-1)

new_vals = []
for i in range(len(all_data)):
    percent = all_data['percent_interval_w_care'][i]
    if percent==-1:
        percent = all_data['percent_interval_w_care_easy'][i] + all_data['percent_interval_w_care_demanding'][i]
        if (all_data['percent_interval_w_care_easy'][i]<0) | (all_data['percent_interval_w_care_demanding'][i]<0):
            percent+=1
        new_vals.append(percent)
    else:
        new_vals.append(percent)
all_data['percent_interval_w_care'] = new_vals

# Return missing vals to missing
all_data = all_data.replace(-1, np.nan)

# Take a peek
all_data
# Out:
#        session items  condition  interval_number  percent_interval_w_care
# 0     SP2018-1   Yes       Easy                1                       95
# 1     SP2018-1   Yes       Easy                2                        5
# 2     SP2018-1   Yes       Easy                3                       85
# 3     SP2018-1   Yes       Easy                4                       20
# 4     SP2018-1   Yes       Easy                5                       70
# 5     SP2018-1   Yes       Easy                6                       35
# 6     SP2018-1   Yes  Demanding                7                       35
# 7     SP2018-1   Yes  Demanding                8                       30
# 8     SP2018-1   Yes  Demanding                9                       15
# 9     SP2018-1   Yes  Demanding               10                       30
# 10    SP2018-1   Yes  Demanding               11                       30
# 11    SP2018-1   Yes  Demanding               12                       20
# 12    SP2018-1   Yes       Easy               13                       15
# 13    SP2018-1   Yes       Easy               14                       15
# 14    SP2018-1   Yes       Easy               15                       20
# 15    SP2018-1   Yes       Easy               16                       15
# 16    SP2018-1   Yes       Easy               17                       15
# 17    SP2018-1   Yes       Easy               18                       15
# 18    SP2018-1   Yes  Demanding               19                       35
# 19    SP2018-1   Yes  Demanding               20                       25
# 20    SP2018-1   Yes  Demanding               21                       20
# 21    SP2018-1   Yes  Demanding               22                       35
# 22    SP2018-1   Yes  Demanding               23                       20
# 23    SP2018-1   Yes  Demanding               24                       30
# 24    SP2018-2   Yes       Easy                1                       20
# 25    SP2018-2   Yes       Easy                2                       20
# 26    SP2018-2   Yes       Easy                3                       20
# 27    SP2018-2   Yes       Easy                4                       20
# 28    SP2018-2   Yes       Easy                5                       15
# 29    SP2018-2   Yes       Easy                6                       20
# 30    SP2018-2   Yes  Demanding                7                       60
# 31    SP2018-2   Yes  Demanding                8                       55
# 32    SP2018-2   Yes  Demanding                9                       45
# 33    SP2018-2   Yes  Demanding               10                       50
# 34    SP2018-2   Yes  Demanding               11                       55
# 35    SP2018-2   Yes  Demanding               12                       50
# 36    SP2018-2   Yes       Easy               13                       15
# 37    SP2018-2   Yes       Easy               14                       15
# 38    SP2018-2   Yes       Easy               15                       15
# 39    SP2018-2   Yes       Easy               16                       15
# 40    SP2018-2   Yes       Easy               17                       15
# 41    SP2018-2   Yes       Easy               18                       15
# 42    SP2018-2   Yes  Demanding               19                       50
# 43    SP2018-2   Yes  Demanding               20                       60
# 44    SP2018-2   Yes  Demanding               21                       50
# 45    SP2018-2   Yes  Demanding               22                       65
# 46    SP2018-2   Yes  Demanding               23                       55
# 47    SP2018-2   Yes  Demanding               24                       55
# 48    SP2018-3   Yes       Easy                1                       15
# 49    SP2018-3   Yes       Easy                2                       15
# 50    SP2018-3   Yes       Easy                3                       10
# 51    SP2018-3   Yes       Easy                4                       20
# 52    SP2018-3   Yes       Easy                5                       15
# 53    SP2018-3   Yes       Easy                6                       25
# 54    SP2018-3   Yes  Demanding                7                       75
# 55    SP2018-3   Yes  Demanding                8                       65
# 56    SP2018-3   Yes  Demanding                9                       60
# 57    SP2018-3   Yes  Demanding               10                       40
# 58    SP2018-3   Yes  Demanding               11                       80
# 59    SP2018-3   Yes  Demanding               12                       40
# 60    SP2018-3   Yes       Easy               13                       20
# 61    SP2018-3   Yes       Easy               14                       20
# 62    SP2018-3   Yes       Easy               15                       20
# 63    SP2018-3   Yes       Easy               16                       20
# 64    SP2018-3   Yes       Easy               17                       10
# 65    SP2018-3   Yes       Easy               18                       10
# 66    SP2018-3   Yes  Demanding               19                       65
# 67    SP2018-3   Yes  Demanding               20                       20
# 68    SP2018-3   Yes  Demanding               21                       45
# 69    SP2018-3   Yes  Demanding               22                       40
# 70    SP2018-3   Yes  Demanding               23                       40
# 71    SP2018-3   Yes  Demanding               24                       35
# 72    SP2018-4   Yes       Easy                1                       25
# 73    SP2018-4   Yes       Easy                2                       10
# 74    SP2018-4   Yes       Easy                3                       15
# 75    SP2018-4   Yes       Easy                4                       15
# 76    SP2018-4   Yes       Easy                5                       15
# 77    SP2018-4   Yes       Easy                6                       15
# 78    SP2018-4   Yes  Demanding                7                       50
# 79    SP2018-4   Yes  Demanding                8                       55
# 80    SP2018-4   Yes  Demanding                9                       75
# 81    SP2018-4   Yes  Demanding               10                       80
# 82    SP2018-4   Yes  Demanding               11                       80
# 83    SP2018-4   Yes  Demanding               12                       65
# 84    SP2018-4   Yes       Easy               13                       20
# 85    SP2018-4   Yes       Easy               14                       20
# 86    SP2018-4   Yes       Easy               15                       15
# 87    SP2018-4   Yes       Easy               16                       10
# 88    SP2018-4   Yes       Easy               17                       15
# 89    SP2018-4   Yes       Easy               18                       10
# 90    SP2018-4   Yes  Demanding               19                       45
# 91    SP2018-4   Yes  Demanding               20                       95
# 92    SP2018-4   Yes  Demanding               21                       90
# 93    SP2018-4   Yes  Demanding               22                      100
# 94    SP2018-4   Yes  Demanding               23                      100
# 95    SP2018-4   Yes  Demanding               24                       90
# 96    FA2018-1    No       Easy                1                       80
# 97    FA2018-1    No       Easy                2                       90
# 98    FA2018-1    No       Easy                3                      100
# 99    FA2018-1    No       Easy                4                       90
# 100   FA2018-1    No       Easy                5                       95
# 101   FA2018-1    No       Easy                6                       90
# 102   FA2018-1    No  Demanding                7                       85
# 103   FA2018-1    No  Demanding                8                       65
# 104   FA2018-1    No  Demanding                9                       75
# 105   FA2018-1    No  Demanding               10                       75
# 106   FA2018-1    No  Demanding               11                       75
# 107   FA2018-1    No  Demanding               12                       65
# 108   FA2018-1    No       Easy               13                       55
# 109   FA2018-1    No       Easy               14                       35
# 110   FA2018-1    No       Easy               15                       20
# 111   FA2018-1    No       Easy               16                       25
# 112   FA2018-1    No       Easy               17                       20
# 113   FA2018-1    No       Easy               18                       25
# 114   FA2018-1    No  Demanding               19                       55
# 115   FA2018-1    No  Demanding               20                       95
# 116   FA2018-1    No  Demanding               21                       85
# 117   FA2018-1    No  Demanding               22                       75
# 118   FA2018-1    No  Demanding               23                       65
# 119   FA2018-1    No  Demanding               24                       60
# 120   FA2018-1    No       Easy               25                       15
# 121   FA2018-1    No       Easy               26                       15
# 122   FA2018-1    No       Easy               27                       15
# 123   FA2018-3    No       Easy                1                       15
# 124   FA2018-3    No       Easy                2                       20
# 125   FA2018-3    No       Easy                3                       25
# 126   FA2018-3    No       Easy                4                       25
# 127   FA2018-3    No       Easy                5                       20
# 128   FA2018-3    No       Easy                6                       25
# 129   FA2018-3    No  Demanding                7                       40
# 130   FA2018-3    No  Demanding                8                       55
# 131   FA2018-3    No  Demanding                9                       55
# 132   FA2018-3    No  Demanding               10                       55
# 133   FA2018-3    No  Demanding               11                       55
# 134   FA2018-3    No  Demanding               12                       50
# 135   FA2018-3    No       Easy               13                       10
# 136   FA2018-3    No       Easy               14                       25
# 137   FA2018-3    No       Easy               15                       20
# 138   FA2018-3    No       Easy               16                       30
# 139   FA2018-3    No       Easy               17                       15
# 140   FA2018-3    No       Easy               18                       15
# 141   FA2018-3    No  Demanding               19                       55
# 142   FA2018-3    No  Demanding               20                       70
# 143   FA2018-3    No  Demanding               21                       60
# 144   FA2018-3    No  Demanding               22                       40
# 145   FA2018-3    No  Demanding               23                       60
# 146   FA2018-3    No  Demanding               24                       75
# 147   FA2018-4    No       Easy                1                       25
# 148   FA2018-4    No       Easy                2                       30
# 149   FA2018-4    No       Easy                3                       35
# 150   FA2018-4    No       Easy                4                       25
# 151   FA2018-4    No       Easy                5                       20
# 152   FA2018-4    No       Easy                6                       30
# 153   FA2018-4    No  Demanding                7                       55
# 154   FA2018-4    No  Demanding                8                       60
# 155   FA2018-4    No  Demanding                9                       60
# 156   FA2018-4    No  Demanding               10                       40
# 157   FA2018-4    No  Demanding               11                       45
# 158   FA2018-4    No  Demanding               12                       40
# 159   FA2018-4    No       Easy               13                       10
# 160   FA2018-4    No       Easy               14                       10
# 161   FA2018-4    No       Easy               15                       15
# 162   FA2018-4    No       Easy               16                        0
# 163   FA2018-4    No       Easy               17                       35
# 164   FA2018-4    No       Easy               18                       10
# 165   FA2018-4    No  Demanding               19                       50
# 166   FA2018-4    No  Demanding               20                       40
# 167   FA2018-4    No  Demanding               21                       20
# 168   FA2018-4    No  Demanding               22                       45
# 169   FA2018-4    No  Demanding               23                       15
# 170   FA2018-4    No  Demanding               24                       30
# 171   FA2018-5    No       Easy                1                       45
# 172   FA2018-5    No       Easy                2                       60
# 173   FA2018-5    No       Easy                3                       40
# 174   FA2018-5    No       Easy                4                       35
# 175   FA2018-5    No       Easy                5                       45
# 176   FA2018-5    No       Easy                6                       15
# 177   FA2018-5    No  Demanding                7                       60
# 178   FA2018-5    No  Demanding                8                       75
# 179   FA2018-5    No  Demanding                9                       65
# 180   FA2018-5    No  Demanding               10                       70
# 181   FA2018-5    No  Demanding               11                       80
# 182   FA2018-5    No  Demanding               12                       55
# 183   FA2018-5    No       Easy               13                       15
# 184   FA2018-5    No       Easy               14                       20
# 185   FA2018-5    No       Easy               15                       15
# 186   FA2018-5    No       Easy               16                       20
# 187   FA2018-5    No       Easy               17                       50
# 188   FA2018-5    No       Easy               18                       30
# 189   FA2018-5    No  Demanding               19                       70
# 190   FA2018-5    No  Demanding               20                       60
# 191   FA2018-5    No  Demanding               21                       65
# 192   FA2018-5    No  Demanding               22                       65
# 193   FA2018-5    No       Easy               23                       20
# 194   FA2018-5    No       Easy               24                       20
# 195   FA2018-5    No       Easy               25                       20
# 196   FA2018-6    No       Easy                1                       95
# 197   FA2018-6    No       Easy                2                       90
# 198   FA2018-6    No       Easy                3                      100
# 199   FA2018-6    No       Easy                4                       90
# 200   FA2018-6    No       Easy                5                       95
# 201   FA2018-6    No       Easy                6                       95
# 202   FA2018-6    No  Demanding                7                       90
# 203   FA2018-6    No  Demanding                8                       85
# 204   FA2018-6    No  Demanding                9                       70
# 205   FA2018-6    No  Demanding               10                       70
# 206   FA2018-6    No  Demanding               11                       60
# 207   FA2018-6    No  Demanding               12                       75
# 208   FA2018-6    No       Easy               13                       30
# 209   FA2018-6    No       Easy               14                       40
# 210   FA2018-6    No       Easy               15                       50
# 211   FA2018-6    No       Easy               16                       55
# 212   FA2018-6    No       Easy               17                       50
# 213   FA2018-6    No       Easy               18                       75
# 214   FA2018-6    No  Demanding               19                       90
# 215   FA2018-6    No  Demanding               20                       60
# 216   FA2018-6    No  Demanding               21                       75
# 217   FA2018-6    No  Demanding               22                       65
# 218   FA2018-6    No  Demanding               23                       50
# 219   FA2018-6    No  Demanding               24                       70
# 220   FA2018-7    No       Easy                1                       85
# 221   FA2018-7    No       Easy                2                       80
# 222   FA2018-7    No       Easy                3                       55
# 223   FA2018-7    No       Easy                4                       80
# 224   FA2018-7    No       Easy                5                       75
# 225   FA2018-7    No       Easy                6                       75
# 226   FA2018-7    No  Demanding                7                       95
# 227   FA2018-7    No  Demanding                8                       95
# 228   FA2018-7    No  Demanding                9                       85
# 229   FA2018-7    No  Demanding               10                       85
# 230   FA2018-7    No  Demanding               11                       60
# 231   FA2018-7    No  Demanding               12                       95
# 232   FA2018-7    No       Easy               13                       65
# 233   FA2018-7    No       Easy               14                       20
# 234   FA2018-7    No       Easy               15                       75
# 235   FA2018-7    No       Easy               16                       60
# 236   FA2018-7    No       Easy               17                       25
# 237   FA2018-7    No       Easy               18                       25
# 238   FA2018-7    No  Demanding               19                       75
# 239   FA2018-7    No  Demanding               20                       65
# 240   FA2018-7    No  Demanding               21                       30
# 241   FA2018-7    No  Demanding               22                       35
# 242   FA2018-7    No  Demanding               23                       10
# 243   FA2018-7    No  Demanding               24                        5
# 244   FA2018-8   Yes       Easy                1                       60
# 245   FA2018-8   Yes       Easy                2                       85
# 246   FA2018-8   Yes       Easy                3                       85
# 247   FA2018-8   Yes       Easy                4                       60
# 248   FA2018-8   Yes       Easy                5                       50
# 249   FA2018-8   Yes       Easy                6                       50
# 250   FA2018-8   Yes  Demanding                7                       60
# 251   FA2018-8   Yes  Demanding                8                       30
# 252   FA2018-8   Yes  Demanding                9                       45
# 253   FA2018-8   Yes  Demanding               10                       45
# 254   FA2018-8   Yes  Demanding               11                       95
# 255   FA2018-8   Yes  Demanding               12                       80
# 256   FA2018-8   Yes       Easy               13                      100
# 257   FA2018-8   Yes       Easy               14                       80
# 258   FA2018-8   Yes       Easy               15                       45
# 259   FA2018-8   Yes       Easy               16                       10
# 260   FA2018-8   Yes       Easy               17                       20
# 261   FA2018-8   Yes       Easy               18                       10
# 262   FA2018-8   Yes  Demanding               19                       85
# 263   FA2018-8   Yes  Demanding               20                       60
# 264   FA2018-8   Yes  Demanding               21                       50
# 265   FA2018-8   Yes  Demanding               22                       35
# 266   FA2018-8   Yes  Demanding               23                       95
# 267   FA2018-8   Yes  Demanding               24                      100
# 268   FA2018-9   Yes       Easy                1                       15
# 269   FA2018-9   Yes       Easy                2                       15
# 270   FA2018-9   Yes       Easy                3                       15
# 271   FA2018-9   Yes       Easy                4                       20
# 272   FA2018-9   Yes       Easy                5                       20
# 273   FA2018-9   Yes       Easy                6                       15
# 274   FA2018-9   Yes  Demanding                7                       55
# 275   FA2018-9   Yes  Demanding                8                       70
# 276   FA2018-9   Yes  Demanding                9                       75
# 277   FA2018-9   Yes  Demanding               10                       75
# 278   FA2018-9   Yes  Demanding               11                       85
# 279   FA2018-9   Yes  Demanding               12                       80
# 280   FA2018-9   Yes       Easy               13                       30
# 281   FA2018-9   Yes       Easy               14                       15
# 282   FA2018-9   Yes       Easy               15                       15
# 283   FA2018-9   Yes       Easy               16                       15
# 284   FA2018-9   Yes  Demanding               17                       80
# 285   FA2018-9   Yes  Demanding               18                       90
# 286   FA2018-9   Yes  Demanding               19                       95
# 287   FA2018-9   Yes  Demanding               20                       85
# 288  FA2018-10   Yes       Easy                1                       15
# 289  FA2018-10   Yes       Easy                2                       20
# 290  FA2018-10   Yes       Easy                3                       20
# 291  FA2018-10   Yes       Easy                4                       20
# 292  FA2018-10   Yes       Easy                5                       15
# 293  FA2018-10   Yes       Easy                6                       15
# 294  FA2018-10   Yes  Demanding                7                       65
# 295  FA2018-10   Yes  Demanding                8                       60
# 296  FA2018-10   Yes  Demanding                9                       65
# 297  FA2018-10   Yes  Demanding               10                       70
# 298  FA2018-10   Yes  Demanding               11                       70
# 299  FA2018-10   Yes  Demanding               12                       70
# 300  FA2018-10   Yes       Easy               13                       20
# 301  FA2018-10   Yes       Easy               14                       20
# 302  FA2018-10   Yes       Easy               15                       20
# 303  FA2018-10   Yes  Demanding               16                       70
# 304  FA2018-10   Yes  Demanding               17                       65
# 305  FA2018-10   Yes  Demanding               18                       65
# 306  FA2018-10   Yes  Demanding               19                       65
# 307  FA2018-11   Yes       Easy                1                       20
# 308  FA2018-11   Yes       Easy                2                       15
# 309  FA2018-11   Yes       Easy                3                       15
# 310  FA2018-11   Yes       Easy                4                       15
# 311  FA2018-11   Yes       Easy                5                       15
# 312  FA2018-11   Yes       Easy                6                       15
# 313  FA2018-11   Yes  Demanding                7                       40
# 314  FA2018-11   Yes  Demanding                8                       60
# 315  FA2018-11   Yes  Demanding                9                       55
# 316  FA2018-11   Yes  Demanding               10                       95
# 317  FA2018-11   Yes  Demanding               11                       30
# 318  FA2018-11   Yes  Demanding               12                       30
# 319  FA2018-11   Yes       Easy               13                        5
# 320  FA2018-11   Yes       Easy               14                        5
# 321  FA2018-11   Yes       Easy               15                       50
# 322  FA2018-11   Yes       Easy               16                        5
# 323  FA2018-11   Yes       Easy               17                        0
# 324  FA2018-11   Yes       Easy               18                       10
# 325  FA2018-11   Yes  Demanding               19                       70
# 326  FA2018-11   Yes  Demanding               20                       30
# 327  FA2018-11   Yes  Demanding               21                       65
# 328  FA2018-11   Yes  Demanding               22                       40
# 329  FA2018-11   Yes  Demanding               23                       65
# 330  FA2018-11   Yes  Demanding               24                       55
# 331  FA2018-12   Yes       Easy                1                       20
# 332  FA2018-12   Yes       Easy                2                       15
# 333  FA2018-12   Yes       Easy                3                       20
# 334  FA2018-12   Yes       Easy                4                       15
# 335  FA2018-12   Yes  Demanding                5                       50
# 336  FA2018-12   Yes  Demanding                6                       55
# 337  FA2018-12   Yes  Demanding                7                       50
# 338  FA2018-12   Yes  Demanding                8                       50
# 339  FA2018-12   Yes       Easy                9                       15
# 340  FA2018-12   Yes       Easy               10                       15
# 341  FA2018-12   Yes       Easy               11                       10
# 342  FA2018-12   Yes  Demanding               12                       50
# 343  FA2018-12   Yes  Demanding               13                       45
# 344  FA2018-12   Yes  Demanding               14                       50
# 345  FA2018-13   Yes       Easy                1                       20
# 346  FA2018-13   Yes       Easy                2                       15
# 347  FA2018-13   Yes       Easy                3                       15
# 348  FA2018-13   Yes       Easy                4                       15
# 349  FA2018-13   Yes  Demanding                5                       50
# 350  FA2018-13   Yes  Demanding                6                       55
# 351  FA2018-13   Yes  Demanding                7                       65
# 352  FA2018-13   Yes  Demanding                8                       55
# 353  FA2018-13   Yes  Demanding                9                       55
# 354  FA2018-13   Yes  Demanding               10                       45
# 355  FA2018-13   Yes       Easy               11                       15
# 356  FA2018-13   Yes       Easy               12                       15
# 357  FA2018-13   Yes       Easy               13                       15
# 358  FA2018-13   Yes  Demanding               14                       70
# 359  FA2018-13   Yes  Demanding               15                       65
# 360  FA2018-13   Yes  Demanding               16                       70

# %%
#Simple plot for easy vs demanding - copied from David's repository

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# trying cividis scale just to see what that looks like
# I don't really notice a difference? 

sns.color_palette("cividis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# trying grey scale just to see what that looks like - - - - wtf. 
# I tried a few things from here: https://matplotlib.org/stable/tutorials/colors/colormaps.html and couldn't figure it out.

sns.color_palette("gist_gray")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# how do I plot just the data with preferred items and then also just the data without preferred items? 

# I first tried adding 'items' in before 'condition' wherever it appeared. 
# I got an error message about position and keywords.
# I then replaced 'condition' with items ... 
# this doesn't show me the mean by conditions - easy vs demanding - for the data with preferred items vs with no
# hm.

sns.color_palette("gist_gray")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['items'], ascending=False), 
    hue='items', 
)
grouped_data = all_data[['items', 'interval_number', 'percent_interval_w_care']].\
                groupby(['items', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='items', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='items', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# to be continued... 
# My questions - how to separate the data - with vs without preferred items? How to break the mean lines? 
#Looking at this again, it's interesting - The most noticable difference, at least to me, is the first easy phase
# intervals 1 through 7 or so, and then also the first demanding phase, intervals 7 through 12 or so... huh.
#fuck.

# %%
# continued .... 

# I created two more excel spreadsheets to separate the data for with vs without access to preferred items. 
# I'm sure there is a way to do it in Python, and I'll circle back to try to figure that out. 

# Just copying and pasting - the original one from David's repository - to take a look at the figures. 

# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# Read in the raw data for no items... 
raw_data = pd.read_excel('Simulated Caregiving - Easy v Demanding - no items.xlsx', sheet_name=None)
data = raw_data.copy()

# Merge all the sheets into a single dataframe and add sheet name as the "sessionæ variable
all_data = pd.DataFrame()
for k in data.keys():
    temp_df = data.get(k)
    temp_df['session'] = k
    all_data = pd.concat([all_data, temp_df])

# Relabel the cols for easier handling
all_data.columns = ['items', 'condition', 'interval_number', 'percent_interval_w_care', 'session']
    
# Reorganize the cols logically
all_data = all_data[[
    'session', 'items', 'condition', 'interval_number', 'percent_interval_w_care'
]].reset_index(drop=True)

# plotting the figure

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# Just repeating for the excel sheet with only the data for access to items
# Gosh, there has to be a way to do this in python - using one data frame, right? 

# Just copying and pasting - the original one from David's repository - to take a look at the figures. 

# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# Read in the raw data for no items... 
raw_data = pd.read_excel('Simulated Caregiving - Easy v Demanding - items only.xlsx', sheet_name=None)
data = raw_data.copy()

# Merge all the sheets into a single dataframe and add sheet name as the "sessionæ variable
all_data = pd.DataFrame()
for k in data.keys():
    temp_df = data.get(k)
    temp_df['session'] = k
    all_data = pd.concat([all_data, temp_df])

# Relabel the cols for easier handling
all_data.columns = ['items', 'condition', 'interval_number', 'percent_interval_w_care', 'session']
    
# Reorganize the cols logically
all_data = all_data[[
    'session', 'items', 'condition', 'interval_number', 'percent_interval_w_care'
]].reset_index(drop=True)

# plotting the figure

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=0, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick)+"%" for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# tinkering with the labels a bit - trying to omit the percentage signs and rotate the y-axis label

plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=-45, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# well, let's try again. 

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage\nof Intervals\nwith Care", fontsize=20, rotation=90, ha="right", labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# heyy, that worked a bit more how I had anticipated. Let's try one more thing to stretch the y-axis label. 

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, ha="right", labelpad=12)
ticks = range(0, 101, 20)
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# Hm. Not what I had anticipated. The label seems to hang below the halfway mark. How to center??

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, labelpad=12)
ticks = range(0, 101, 20)
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# ha, no way. cool. 

# So, my questions thus far: 
# How to show the data separated by items vs. no items and also easy vs. demanding? without using separate sheets.
# How to change the legend? And how to break the mean lines... Is that needed? 
# Grayscale? 
# Also, is there another display option that would show individual data and also the mean? Hm...
