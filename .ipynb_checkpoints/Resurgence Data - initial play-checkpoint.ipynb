# %%
# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
raw_data = pd.read_excel('Toys_Resurgence.xlsx', sheet_name=None)
all_data = raw_data.copy()

all_data
# Out:
# {'Particpant1':       Cumulative Seconds  Condition  Session Seconds  Toy 1  Toy 2  Toy 3  \
#  0                      1  Toy 1 Sr-                1      0      0      0
#  1                      2  Toy 1 Sr-                2      0      0      0
#  2                      3  Toy 1 Sr-                3      0      0      0
#  3                      4  Toy 1 Sr-                4      0      0      0
#  4                      5  Toy 1 Sr-                5      0      0      0
#  5                      6  Toy 1 Sr-                6      0      0      0
#  6                      7  Toy 1 Sr-                7      0      0      0
#  7                      8  Toy 1 Sr-                8      1      0      0
#  8                      9  Toy 1 Sr-                9      2      0      0
#  9                     10  Toy 1 Sr-               10      3      0      0
#  10                    11  Toy 1 Sr-               11      4      0      0
# ...

# %%
# Okay, I have some ideas for cleaning the excel spreadsheet to make it a bit easier here. I'll be back.
