# %%
# this is the notebook that is using the most updated and complete spreadsheet, with the additional datasets included... 

# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
raw_data = pd.read_excel('Simulated Caregiving - Easy v Demanding - ALL.xlsx', sheet_name=None)
data = raw_data.copy()


all_data = pd.DataFrame()

for k in data.keys():
    temp_df = data.get(k)
    temp_df['session'] = k
    all_data = pd.concat([all_data, temp_df])

# %%
# Relabel the cols for easier handling
all_data.columns = ['dolls', 'items', 'condition', 'interval_number', 'percent_interval_w_care', 'session']

# Reorganize the cols logically
all_data = all_data[[
    'session', 'dolls', 'items', 'condition', 'interval_number', 'percent_interval_w_care'
]].reset_index(drop=True)

# %%
#Simple plot for easy vs demanding - mostly copied from David's repository, with a few mods for my preferences

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=all_data.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = all_data[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# for next time - break the lines, change to gray scale, change the legend.
# other visualizations? S-S figs too or bars for means?

# %%
# And, back. I'm actually going to try graphing only some rows, based on column values.
# https://www.statology.org/pandas-select-rows-based-on-column-values/

items_data = all_data.loc[all_data['items'] == 'Yes']

items_data
# Out:
#        session dolls items  condition  interval_number  \
# 0     SP2018-1   One   Yes       Easy                1
# 1     SP2018-1   One   Yes       Easy                2
# 2     SP2018-1   One   Yes       Easy                3
# 3     SP2018-1   One   Yes       Easy                4
# 4     SP2018-1   One   Yes       Easy                5
# 5     SP2018-1   One   Yes       Easy                6
# 6     SP2018-1   One   Yes  Demanding                7
# 7     SP2018-1   One   Yes  Demanding                8
# 8     SP2018-1   One   Yes  Demanding                9
# 9     SP2018-1   One   Yes  Demanding               10
# 10    SP2018-1   One   Yes  Demanding               11
# 11    SP2018-1   One   Yes  Demanding               12
# 12    SP2018-1   One   Yes       Easy               13
# 13    SP2018-1   One   Yes       Easy               14
# 14    SP2018-1   One   Yes       Easy               15
# 15    SP2018-1   One   Yes       Easy               16
# 16    SP2018-1   One   Yes       Easy               17
# 17    SP2018-1   One   Yes       Easy               18
# 18    SP2018-1   One   Yes  Demanding               19
# 19    SP2018-1   One   Yes  Demanding               20
# 20    SP2018-1   One   Yes  Demanding               21
# 21    SP2018-1   One   Yes  Demanding               22
# 22    SP2018-1   One   Yes  Demanding               23
# 23    SP2018-1   One   Yes  Demanding               24
# 24    SP2018-2   One   Yes       Easy                1
# 25    SP2018-2   One   Yes       Easy                2
# 26    SP2018-2   One   Yes       Easy                3
# 27    SP2018-2   One   Yes       Easy                4
# 28    SP2018-2   One   Yes       Easy                5
# 29    SP2018-2   One   Yes       Easy                6
# 30    SP2018-2   One   Yes  Demanding                7
# 31    SP2018-2   One   Yes  Demanding                8
# 32    SP2018-2   One   Yes  Demanding                9
# 33    SP2018-2   One   Yes  Demanding               10
# 34    SP2018-2   One   Yes  Demanding               11
# 35    SP2018-2   One   Yes  Demanding               12
# 36    SP2018-2   One   Yes       Easy               13
# 37    SP2018-2   One   Yes       Easy               14
# 38    SP2018-2   One   Yes       Easy               15
# 39    SP2018-2   One   Yes       Easy               16
# 40    SP2018-2   One   Yes       Easy               17
# 41    SP2018-2   One   Yes       Easy               18
# 42    SP2018-2   One   Yes  Demanding               19
# 43    SP2018-2   One   Yes  Demanding               20
# 44    SP2018-2   One   Yes  Demanding               21
# 45    SP2018-2   One   Yes  Demanding               22
# 46    SP2018-2   One   Yes  Demanding               23
# 47    SP2018-2   One   Yes  Demanding               24
# 48    SP2018-3   One   Yes       Easy                1
# 49    SP2018-3   One   Yes       Easy                2
# 50    SP2018-3   One   Yes       Easy                3
# 51    SP2018-3   One   Yes       Easy                4
# 52    SP2018-3   One   Yes       Easy                5
# 53    SP2018-3   One   Yes       Easy                6
# 54    SP2018-3   One   Yes  Demanding                7
# 55    SP2018-3   One   Yes  Demanding                8
# 56    SP2018-3   One   Yes  Demanding                9
# 57    SP2018-3   One   Yes  Demanding               10
# 58    SP2018-3   One   Yes  Demanding               11
# 59    SP2018-3   One   Yes  Demanding               12
# 60    SP2018-3   One   Yes       Easy               13
# 61    SP2018-3   One   Yes       Easy               14
# 62    SP2018-3   One   Yes       Easy               15
# 63    SP2018-3   One   Yes       Easy               16
# 64    SP2018-3   One   Yes       Easy               17
# 65    SP2018-3   One   Yes       Easy               18
# 66    SP2018-3   One   Yes  Demanding               19
# 67    SP2018-3   One   Yes  Demanding               20
# 68    SP2018-3   One   Yes  Demanding               21
# 69    SP2018-3   One   Yes  Demanding               22
# 70    SP2018-3   One   Yes  Demanding               23
# 71    SP2018-3   One   Yes  Demanding               24
# 72    SP2018-4   One   Yes       Easy                1
# 73    SP2018-4   One   Yes       Easy                2
# 74    SP2018-4   One   Yes       Easy                3
# 75    SP2018-4   One   Yes       Easy                4
# 76    SP2018-4   One   Yes       Easy                5
# 77    SP2018-4   One   Yes       Easy                6
# 78    SP2018-4   One   Yes  Demanding                7
# 79    SP2018-4   One   Yes  Demanding                8
# 80    SP2018-4   One   Yes  Demanding                9
# 81    SP2018-4   One   Yes  Demanding               10
# 82    SP2018-4   One   Yes  Demanding               11
# 83    SP2018-4   One   Yes  Demanding               12
# 84    SP2018-4   One   Yes       Easy               13
# 85    SP2018-4   One   Yes       Easy               14
# 86    SP2018-4   One   Yes       Easy               15
# 87    SP2018-4   One   Yes       Easy               16
# 88    SP2018-4   One   Yes       Easy               17
# 89    SP2018-4   One   Yes       Easy               18
# 436   SP2019-4   One   Yes       Easy                6
# 437   SP2019-4   One   Yes  Demanding                7
# 438   SP2019-4   One   Yes  Demanding                8
# 439   SP2019-4   One   Yes  Demanding                9
# 440   SP2019-4   One   Yes       Easy               10
# 441   SP2019-4   One   Yes       Easy               11
# 442   SP2019-4   Two   Yes       Easy               12
# 443   SP2019-4   Two   Yes  Demanding               12
# 444   SP2019-4   Two   Yes       Easy               13
# 445   SP2019-4   Two   Yes  Demanding               13
# 446   SP2019-4   Two   Yes       Easy               14
# 447   SP2019-4   Two   Yes  Demanding               14
#
#      percent_interval_w_care
# 0                       95.0
# 1                        5.0
# 2                       85.0
# 3                       20.0
# 4                       70.0
# 5                       35.0
# 6                       35.0
# 7                       30.0
# 8                       15.0
# 9                       30.0
# 10                      30.0
# 11                      20.0
# 12                      15.0
# 13                      15.0
# 14                      20.0
# 15                      15.0
# 16                      15.0
# 17                      15.0
# 18                      35.0
# 19                      25.0
# 20                      20.0
# 21                      35.0
# 22                      20.0
# 23                      30.0
# 24                      20.0
# 25                      20.0
# 26                      20.0
# 27                      20.0
# 28                      15.0
# 29                      20.0
# 30                      60.0
# 31                      55.0
# 32                      45.0
# 33                      50.0
# 34                      55.0
# 35                      50.0
# 36                      15.0
# 37                      15.0
# 38                      15.0
# 39                      15.0
# 40                      15.0
# 41                      15.0
# 42                      50.0
# 43                      60.0
# 44                      50.0
# 45                      65.0
# 46                      55.0
# 47                      55.0
# 48                      15.0
# 49                      15.0
# 50                      10.0
# 51                      20.0
# 52                      15.0
# 53                      25.0
# 54                      75.0
# 55                      65.0
# 56                      60.0
# 57                      40.0
# 58                      80.0
# 59                      40.0
# 60                      20.0
# 61                      20.0
# 62                      20.0
# 63                      20.0
# 64                      10.0
# 65                      10.0
# 66                      65.0
# 67                      20.0
# 68                      45.0
# 69                      40.0
# 70                      40.0
# 71                      35.0
# 72                      25.0
# 73                      10.0
# 74                      15.0
# 75                      15.0
# 76                      15.0
# 77                      15.0
# 78                      50.0
# 79                      55.0
# 80                      75.0
# 81                      80.0
# 82                      80.0
# 83                      65.0
# 84                      20.0
# 85                      20.0
# 86                      15.0
# 87                      10.0
# 88                      15.0
# 89                      10.0
# 90                      45.0
# 91                      95.0
# 92                      90.0
# 93                     100.0
# 94                     100.0
# 95                      90.0
# 244                     60.0
# 245                     85.0
# 246                     85.0
# 247                     60.0
# 248                     50.0
# 249                     50.0
# 250                     60.0
# 251                     30.0
# 252                     45.0
# 253                     45.0
# 254                     95.0
# 255                     80.0
# 256                    100.0
# 257                     80.0
# 258                     45.0
# 259                     10.0
# 260                     20.0
# 261                     10.0
# 262                     85.0
# 263                     60.0
# 264                     50.0
# 265                     35.0
# 266                     95.0
# 267                    100.0
# 268                     15.0
# 269                     15.0
# 270                     15.0
# 271                     20.0
# 272                     20.0
# 273                     15.0
# 274                     55.0
# 275                     70.0
# 276                     75.0
# 277                     75.0
# 278                     85.0
# 279                     80.0
# 280                     30.0
# 281                     15.0
# 282                     15.0
# 283                     15.0
# 284                     80.0
# 285                     90.0
# 286                     95.0
# 287                     85.0
# 288                     15.0
# 289                     20.0
# 290                     20.0
# 291                     20.0
# 292                     15.0
# 293                     15.0
# 294                     65.0
# 295                     60.0
# 296                     65.0
# 297                     70.0
# 298                     70.0
# 299                     70.0
# 300                     20.0
# 301                     20.0
# 302                     20.0
# 303                     70.0
# 304                     65.0
# 305                     65.0
# 306                     65.0
# 307                     20.0
# 308                     15.0
# 309                     15.0
# 310                     15.0
# 311                     15.0
# 312                     15.0
# 313                     40.0
# 314                     60.0
# 315                     55.0
# 316                     95.0
# 317                     30.0
# 318                     30.0
# 319                      5.0
# 320                      5.0
# 321                     50.0
# 322                      5.0
# 323                      0.0
# 324                     10.0
# 325                     70.0
# 326                     30.0
# 327                     65.0
# 328                     40.0
# 329                     65.0
# 330                     55.0
# 331                     20.0
# 332                     15.0
# 333                     20.0
# 334                     15.0
# 335                     50.0
# 336                     55.0
# 337                     50.0
# 338                     50.0
# 339                     15.0
# 340                     15.0
# 341                     10.0
# 342                     50.0
# 343                     45.0
# 344                     50.0
# 345                     20.0
# 346                     15.0
# 347                     15.0
# 348                     15.0
# 349                     50.0
# 350                     55.0
# 351                     65.0
# 352                     55.0
# 353                     55.0
# 354                     45.0
# 355                     15.0
# 356                     15.0
# 357                     15.0
# 358                     70.0
# 359                     65.0
# 360                     70.0
# 361                     15.0
# 362                     15.0
# 363                     15.0
# 364                     50.0
# 365                     70.0
# 366                    100.0
# 367                     15.0
# 368                     20.0
# 369                     15.0
# 370                     55.0
# 371                     70.0
# 372                     65.0
# 373                     15.0
# 374                     50.0
# 375                     30.0
# 376                     55.0
# 377                     10.0
# 378                     65.0
# 379                     15.0
# 380                     55.0
# 381                     10.0
# 382                     50.0
# 383                     15.0
# 384                     15.0
# 385                     20.0
# 386                     25.0
# 387                     20.0
# 388                     20.0
# 389                     55.0
# 390                     65.0
# 391                     70.0
# 392                     15.0
# 393                     55.0
# 394                     20.0
# 395                     50.0
# 396                      5.0
# 397                     50.0
# 398                     10.0
# 399                     50.0
# 400                     15.0
# 401                     15.0
# 402                     15.0
# 403                     15.0
# 404                     45.0
# 405                     60.0
# 406                     50.0
# 407                     15.0
# 408                     40.0
# 409                     20.0
# 410                     50.0
# 411                     10.0
# 412                     55.0
# 413                     70.0
# 414                     50.0
# 415                     55.0
# 416                     45.0
# 417                     75.0
# 418                     50.0
# 419                     70.0
# 420                     75.0
# 421                     80.0
# 422                     85.0
# 423                     65.0
# 424                     60.0
# 425                     25.0
# 426                     45.0
# 427                     20.0
# 428                     50.0
# 429                     10.0
# 430                     70.0
# 431                     95.0
# 432                     90.0
# 433                    100.0
# 434                     20.0
# 435                     20.0
# 436                     20.0
# 437                     70.0
# 438                     70.0
# 439                     75.0
# 440                     20.0
# 441                     20.0
# 442                     20.0
# 443                     50.0
# 444                     15.0
# 445                     60.0
# 446                     15.0
# 447                     55.0

# %%
# Okay, neat. Now, Items & only one doll... 

items_OneDoll = all_data.loc[(all_data['items'] == 'Yes') & (all_data['dolls'] == 'One')]

items_OneDoll
# Out:
#        session dolls items  condition  interval_number  \
# 0     SP2018-1   One   Yes       Easy                1
# 7                       30.0
# 8                       15.0
# 9                       30.0
# 10                      30.0
# 11                      20.0
# 12                      15.0
# 13                      15.0
# 14                      20.0
# 15                      15.0
# 16                      15.0
# 17                      15.0
# 18                      35.0
# 19                      25.0
# 20                      20.0
# 21                      35.0
# 22                      20.0
# 23                      30.0
# 24                      20.0
# 25                      20.0
# 26                      20.0
# 27                      20.0
# 28                      15.0
# 29                      20.0
# 30                      60.0
# 31                      55.0
# 32                      45.0
# 33                      50.0
# 34                      55.0
# 35                      50.0
# 36                      15.0
# 37                      15.0
# 38                      15.0
# 39                      15.0
# 40                      15.0
# 41                      15.0
# 42                      50.0
# 43                      60.0
# 44                      50.0
# 45                      65.0
# 46                      55.0
# 47                      55.0
# 48                      15.0
# 49                      15.0
# 50                      10.0
# 51                      20.0
# 52                      15.0
# 53                      25.0
# 54                      75.0
# 55                      65.0
# 56                      60.0
# 57                      40.0
# 58                      80.0
# 59                      40.0
# 60                      20.0
# 61                      20.0
# 62                      20.0
# 63                      20.0
# 64                      10.0
# 65                      10.0
# 66                      65.0
# 67                      20.0
# 68                      45.0
# 69                      40.0
# 70                      40.0
# 71                      35.0
# 72                      25.0
# 73                      10.0
# 74                      15.0
# 75                      15.0
# 76                      15.0
# 77                      15.0
# 78                      50.0
# 79                      55.0
# 80                      75.0
# 81                      80.0
# 82                      80.0
# 83                      65.0
# 84                      20.0
# 85                      20.0
# 86                      15.0
# 87                      10.0
# 88                      15.0
# 89                      10.0
# 90                      45.0
# 91                      95.0
# 92                      90.0
# 93                     100.0
# 94                     100.0
# 95                      90.0
# 244                     60.0
# 245                     85.0
# 246                     85.0
# 247                     60.0
# 248                     50.0
# 249                     50.0
# 250                     60.0
# 251                     30.0
# 252                     45.0
# 253                     45.0
# 254                     95.0
# 255                     80.0
# 256                    100.0
# 257                     80.0
# 258                     45.0
# 259                     10.0
# 260                     20.0
# 261                     10.0
# 262                     85.0
# 263                     60.0
# 264                     50.0
# 265                     35.0
# 266                     95.0
# 267                    100.0
# 268                     15.0
# 269                     15.0
# 270                     15.0
# 271                     20.0
# 272                     20.0
# 273                     15.0
# 274                     55.0
# 275                     70.0
# 276                     75.0
# 277                     75.0
# 278                     85.0
# 279                     80.0
# 280                     30.0
# 281                     15.0
# 282                     15.0
# 283                     15.0
# 284                     80.0
# 285                     90.0
# 286                     95.0
# 287                     85.0
# 288                     15.0
# 289                     20.0
# 290                     20.0
# 291                     20.0
# 292                     15.0
# 293                     15.0
# 294                     65.0
# 295                     60.0
# 296                     65.0
# 297                     70.0
# 298                     70.0
# 299                     70.0
# 300                     20.0
# 301                     20.0
# 302                     20.0
# 303                     70.0
# 304                     65.0
# 305                     65.0
# 306                     65.0
# 307                     20.0
# 308                     15.0
# 309                     15.0
# 310                     15.0
# 311                     15.0
# 312                     15.0
# 313                     40.0
# 314                     60.0
# 315                     55.0
# 316                     95.0
# 317                     30.0
# 318                     30.0
# 319                      5.0
# 320                      5.0
# 321                     50.0
# 322                      5.0
# 323                      0.0
# 324                     10.0
# 325                     70.0
# 326                     30.0
# 327                     65.0
# 328                     40.0
# 329                     65.0
# 330                     55.0
# 331                     20.0
# 332                     15.0
# 333                     20.0
# 334                     15.0
# 335                     50.0
# 336                     55.0
# 337                     50.0
# 338                     50.0
# 339                     15.0
# 340                     15.0
# 341                     10.0
# 342                     50.0
# 343                     45.0
# 344                     50.0
# 345                     20.0
# 346                     15.0
# 347                     15.0
# 348                     15.0
# 349                     50.0
# 350                     55.0
# 351                     65.0
# 352                     55.0
# 353                     55.0
# 354                     45.0
# 355                     15.0
# 356                     15.0
# 357                     15.0
# 358                     70.0
# 359                     65.0
# 360                     70.0
# 361                     15.0
# 362                     15.0
# 363                     15.0
# 364                     50.0
# 365                     70.0
# 366                    100.0
# 367                     15.0
# 368                     20.0
# 369                     15.0
# 370                     55.0
# 371                     70.0
# 372                     65.0
# 383                     15.0
# 384                     15.0
# 385                     20.0
# 386                     25.0
# 387                     20.0
# 388                     20.0
# 389                     55.0
# 390                     65.0
# 391                     70.0
# 400                     15.0
# 401                     15.0
# 402                     15.0
# 403                     15.0
# 404                     45.0
# 405                     60.0
# 406                     50.0
# 413                     70.0
# 414                     50.0
# 415                     55.0
# 416                     45.0
# 417                     75.0
# 418                     50.0
# 419                     70.0
# 420                     75.0
# 421                     80.0
# 422                     85.0
# 423                     65.0
# 424                     60.0
# 431                     95.0
# 432                     90.0
# 433                    100.0
# 434                     20.0
# 435                     20.0
# 436                     20.0
# 437                     70.0
# 438                     70.0
# 439                     75.0
# 440                     20.0
# 441                     20.0

# %%
# Simple plot of the Items & One Doll (easy vs. demanding) data... 

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=items_OneDoll.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = items_OneDoll[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# Interesting. Now, no items & one doll... 

No_items_OneDoll = all_data.loc[(all_data['items'] == 'No') & (all_data['dolls'] == 'One')]

No_items_OneDoll
# Out:
#       session dolls items  condition  interval_number  percent_interval_w_care
# 96   FA2018-1   One    No       Easy                1                     80.0
# 97   FA2018-1   One    No       Easy                2                     90.0
# 98   FA2018-1   One    No       Easy                3                    100.0
# 99   FA2018-1   One    No       Easy                4                     90.0
# 100  FA2018-1   One    No       Easy                5                     95.0
# 101  FA2018-1   One    No       Easy                6                     90.0
# 102  FA2018-1   One    No  Demanding                7                     85.0
# 103  FA2018-1   One    No  Demanding                8                     65.0
# 104  FA2018-1   One    No  Demanding                9                     75.0
# 105  FA2018-1   One    No  Demanding               10                     75.0
# 106  FA2018-1   One    No  Demanding               11                     75.0
# 107  FA2018-1   One    No  Demanding               12                     65.0
# 108  FA2018-1   One    No       Easy               13                     55.0
# 109  FA2018-1   One    No       Easy               14                     35.0
# 110  FA2018-1   One    No       Easy               15                     20.0
# 111  FA2018-1   One    No       Easy               16                     25.0
# 112  FA2018-1   One    No       Easy               17                     20.0
# 113  FA2018-1   One    No       Easy               18                     25.0
# 114  FA2018-1   One    No  Demanding               19                     55.0
# 115  FA2018-1   One    No  Demanding               20                     95.0
# 116  FA2018-1   One    No  Demanding               21                     85.0
# 117  FA2018-1   One    No  Demanding               22                     75.0
# 118  FA2018-1   One    No  Demanding               23                     65.0
# 119  FA2018-1   One    No  Demanding               24                     60.0
# 120  FA2018-1   One    No       Easy               25                     15.0
# 121  FA2018-1   One    No       Easy               26                     15.0
# 122  FA2018-1   One    No       Easy               27                     15.0
# 123  FA2018-3   One    No       Easy                1                     15.0
# 124  FA2018-3   One    No       Easy                2                     20.0
# 125  FA2018-3   One    No       Easy                3                     25.0
# 126  FA2018-3   One    No       Easy                4                     25.0
# 127  FA2018-3   One    No       Easy                5                     20.0
# 128  FA2018-3   One    No       Easy                6                     25.0
# 129  FA2018-3   One    No  Demanding                7                     40.0
# 130  FA2018-3   One    No  Demanding                8                     55.0
# 131  FA2018-3   One    No  Demanding                9                     55.0
# 132  FA2018-3   One    No  Demanding               10                     55.0
# 133  FA2018-3   One    No  Demanding               11                     55.0
# 134  FA2018-3   One    No  Demanding               12                     50.0
# 135  FA2018-3   One    No       Easy               13                     10.0
# 136  FA2018-3   One    No       Easy               14                     25.0
# 137  FA2018-3   One    No       Easy               15                     20.0
# 138  FA2018-3   One    No       Easy               16                     30.0
# 139  FA2018-3   One    No       Easy               17                     15.0
# 140  FA2018-3   One    No       Easy               18                     15.0
# 141  FA2018-3   One    No  Demanding               19                     55.0
# 142  FA2018-3   One    No  Demanding               20                     70.0
# 143  FA2018-3   One    No  Demanding               21                     60.0
# 144  FA2018-3   One    No  Demanding               22                     40.0
# 145  FA2018-3   One    No  Demanding               23                     60.0
# 146  FA2018-3   One    No  Demanding               24                     75.0
# 147  FA2018-4   One    No       Easy                1                     25.0
# 148  FA2018-4   One    No       Easy                2                     30.0
# 149  FA2018-4   One    No       Easy                3                     35.0
# 150  FA2018-4   One    No       Easy                4                     25.0
# 151  FA2018-4   One    No       Easy                5                     20.0
# 152  FA2018-4   One    No       Easy                6                     30.0
# 153  FA2018-4   One    No  Demanding                7                     55.0
# 154  FA2018-4   One    No  Demanding                8                     60.0
# 155  FA2018-4   One    No  Demanding                9                     60.0
# 156  FA2018-4   One    No  Demanding               10                     40.0
# 157  FA2018-4   One    No  Demanding               11                     45.0
# 158  FA2018-4   One    No  Demanding               12                     40.0
# 159  FA2018-4   One    No       Easy               13                     10.0
# 160  FA2018-4   One    No       Easy               14                     10.0
# 161  FA2018-4   One    No       Easy               15                     15.0
# 162  FA2018-4   One    No       Easy               16                      0.0
# 163  FA2018-4   One    No       Easy               17                     35.0
# 164  FA2018-4   One    No       Easy               18                     10.0
# 165  FA2018-4   One    No  Demanding               19                     50.0
# 166  FA2018-4   One    No  Demanding               20                     40.0
# 167  FA2018-4   One    No  Demanding               21                     20.0
# 168  FA2018-4   One    No  Demanding               22                     45.0
# 169  FA2018-4   One    No  Demanding               23                     15.0
# 170  FA2018-4   One    No  Demanding               24                     30.0
# 171  FA2018-5   One    No       Easy                1                     45.0
# 172  FA2018-5   One    No       Easy                2                     60.0
# 173  FA2018-5   One    No       Easy                3                     40.0
# 174  FA2018-5   One    No       Easy                4                     35.0
# 175  FA2018-5   One    No       Easy                5                     45.0
# 176  FA2018-5   One    No       Easy                6                     15.0
# 177  FA2018-5   One    No  Demanding                7                     60.0
# 178  FA2018-5   One    No  Demanding                8                     75.0
# 179  FA2018-5   One    No  Demanding                9                     65.0
# 180  FA2018-5   One    No  Demanding               10                     70.0
# 181  FA2018-5   One    No  Demanding               11                     80.0
# 182  FA2018-5   One    No  Demanding               12                     55.0
# 183  FA2018-5   One    No       Easy               13                     15.0
# 184  FA2018-5   One    No       Easy               14                     20.0
# 185  FA2018-5   One    No       Easy               15                     15.0
# 186  FA2018-5   One    No       Easy               16                     20.0
# 187  FA2018-5   One    No       Easy               17                     50.0
# 188  FA2018-5   One    No       Easy               18                     30.0
# 189  FA2018-5   One    No  Demanding               19                     70.0
# 190  FA2018-5   One    No  Demanding               20                     60.0
# 191  FA2018-5   One    No  Demanding               21                     65.0
# 192  FA2018-5   One    No  Demanding               22                     65.0
# 193  FA2018-5   One    No       Easy               23                     20.0
# 194  FA2018-5   One    No       Easy               24                     20.0
# 195  FA2018-5   One    No       Easy               25                     20.0
# 196  FA2018-6   One    No       Easy                1                     95.0
# 197  FA2018-6   One    No       Easy                2                     90.0
# 198  FA2018-6   One    No       Easy                3                    100.0
# 199  FA2018-6   One    No       Easy                4                     90.0
# 200  FA2018-6   One    No       Easy                5                     95.0
# 201  FA2018-6   One    No       Easy                6                     95.0
# 202  FA2018-6   One    No  Demanding                7                     90.0
# 203  FA2018-6   One    No  Demanding                8                     85.0
# 204  FA2018-6   One    No  Demanding                9                     70.0
# 205  FA2018-6   One    No  Demanding               10                     70.0
# 206  FA2018-6   One    No  Demanding               11                     60.0
# 207  FA2018-6   One    No  Demanding               12                     75.0
# 208  FA2018-6   One    No       Easy               13                     30.0
# 209  FA2018-6   One    No       Easy               14                     40.0
# 210  FA2018-6   One    No       Easy               15                     50.0
# 211  FA2018-6   One    No       Easy               16                     55.0
# 212  FA2018-6   One    No       Easy               17                     50.0
# 213  FA2018-6   One    No       Easy               18                     75.0
# 214  FA2018-6   One    No  Demanding               19                     90.0
# 215  FA2018-6   One    No  Demanding               20                     60.0
# 216  FA2018-6   One    No  Demanding               21                     75.0
# 217  FA2018-6   One    No  Demanding               22                     65.0
# 218  FA2018-6   One    No  Demanding               23                     50.0
# 219  FA2018-6   One    No  Demanding               24                     70.0
# 220  FA2018-7   One    No       Easy                1                     85.0
# 221  FA2018-7   One    No       Easy                2                     80.0
# 222  FA2018-7   One    No       Easy                3                     55.0
# 223  FA2018-7   One    No       Easy                4                     80.0
# 224  FA2018-7   One    No       Easy                5                     75.0
# 225  FA2018-7   One    No       Easy                6                     75.0
# 226  FA2018-7   One    No  Demanding                7                     95.0
# 227  FA2018-7   One    No  Demanding                8                     95.0
# 228  FA2018-7   One    No  Demanding                9                     85.0
# 229  FA2018-7   One    No  Demanding               10                     85.0
# 230  FA2018-7   One    No  Demanding               11                     60.0
# 231  FA2018-7   One    No  Demanding               12                     95.0
# 232  FA2018-7   One    No       Easy               13                     65.0
# 233  FA2018-7   One    No       Easy               14                     20.0
# 234  FA2018-7   One    No       Easy               15                     75.0
# 235  FA2018-7   One    No       Easy               16                     60.0
# 236  FA2018-7   One    No       Easy               17                     25.0
# 237  FA2018-7   One    No       Easy               18                     25.0
# 238  FA2018-7   One    No  Demanding               19                     75.0
# 239  FA2018-7   One    No  Demanding               20                     65.0
# 240  FA2018-7   One    No  Demanding               21                     30.0
# 241  FA2018-7   One    No  Demanding               22                     35.0
# 242  FA2018-7   One    No  Demanding               23                     10.0
# 243  FA2018-7   One    No  Demanding               24                      5.0

# %%
# Simple plot of the No Items & One doll (easy vs. demanding) data... 

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=No_items_OneDoll.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = No_items_OneDoll[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# Okay, seems right. Now, Items & Two Dolls (easy vs. demanding) data... 

items_TwoDolls = all_data.loc[(all_data['items'] == 'Yes') & (all_data['dolls'] == 'Two')]

items_TwoDolls
# Out:
#        session dolls items  condition  interval_number  \
# 373  FA2018-14   Two   Yes       Easy               13
# 374  FA2018-14   Two   Yes  Demanding               13
# 375  FA2018-14   Two   Yes       Easy               14
# 376  FA2018-14   Two   Yes  Demanding               14
# 377  FA2018-14   Two   Yes       Easy               15
# 378  FA2018-14   Two   Yes  Demanding               15
# 379  FA2018-14   Two   Yes       Easy               16
# 380  FA2018-14   Two   Yes  Demanding               16
# 381  FA2018-14   Two   Yes       Easy               17
# 382  FA2018-14   Two   Yes  Demanding               17
# 392   SP2019-1   Two   Yes       Easy               10
# 393   SP2019-1   Two   Yes  Demanding               10
# 394   SP2019-1   Two   Yes       Easy               11
# 395   SP2019-1   Two   Yes  Demanding               11
# 396   SP2019-1   Two   Yes       Easy               12
# 397   SP2019-1   Two   Yes  Demanding               12
# 398   SP2019-1   Two   Yes       Easy               13
# 399   SP2019-1   Two   Yes  Demanding               13
# 407   SP2019-2   Two   Yes       Easy                8
# 408   SP2019-2   Two   Yes  Demanding                8
# 409   SP2019-2   Two   Yes       Easy                9
# 410   SP2019-2   Two   Yes  Demanding                9
# 411   SP2019-2   Two   Yes       Easy               10
# 412   SP2019-2   Two   Yes  Demanding               10
# 425   SP2019-3   Two   Yes       Easy               13
# 426   SP2019-3   Two   Yes  Demanding               13
# 427   SP2019-3   Two   Yes       Easy               14
# 428   SP2019-3   Two   Yes  Demanding               14
# 429   SP2019-3   Two   Yes       Easy               15
# 430   SP2019-3   Two   Yes  Demanding               15
# 442   SP2019-4   Two   Yes       Easy               12
# 443   SP2019-4   Two   Yes  Demanding               12
# 444   SP2019-4   Two   Yes       Easy               13
# 445   SP2019-4   Two   Yes  Demanding               13
# 446   SP2019-4   Two   Yes       Easy               14
# 447   SP2019-4   Two   Yes  Demanding               14
#
#      percent_interval_w_care
# 373                     15.0
# 374                     50.0
# 375                     30.0
# 376                     55.0
# 377                     10.0
# 378                     65.0
# 379                     15.0
# 380                     55.0
# 381                     10.0
# 382                     50.0
# 392                     15.0
# 393                     55.0
# 394                     20.0
# 395                     50.0
# 396                      5.0
# 397                     50.0
# 398                     10.0
# 399                     50.0
# 407                     15.0
# 408                     40.0
# 409                     20.0
# 410                     50.0
# 411                     10.0
# 412                     55.0
# 425                     25.0
# 426                     45.0
# 427                     20.0
# 428                     50.0
# 429                     10.0
# 430                     70.0
# 442                     20.0
# 443                     50.0
# 444                     15.0
# 445                     60.0
# 446                     15.0
# 447                     55.0

# %%
# Simple plot of the Items & Two Dolls (easy vs. demanding) data

sns.color_palette("viridis")
fig, ax = plt.subplots(figsize=(13, 7))
sns.stripplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=items_TwoDolls.sort_values(by=['condition'], ascending=False), 
    hue='condition', 
)
grouped_data = items_TwoDolls[['condition', 'interval_number', 'percent_interval_w_care']].\
                groupby(['condition', 'interval_number'])['percent_interval_w_care'].mean().\
                reset_index().sort_values(by='condition', ascending=False).reset_index(drop=True)
sns.lineplot(
    x='interval_number', 
    y='percent_interval_w_care', 
    data=grouped_data, 
    hue='condition', 
)
plt.ylabel("Percentage of Intervals with Care", fontsize=20, rotation=90, labelpad=12)
ticks = range(0, 101, 20)
labels = [str(tick) for tick in ticks]
plt.yticks(ticks=ticks, labels=labels, fontsize=16)
plt.xlabel("5-Min Interval within Session", fontsize=20, labelpad=12)
plt.xticks(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.legend(loc=(1.02, 0.5), frameon=False, fontsize=18)
plt.show()

# %%
# Interesting. These data look the most orderly to me (aside from the mismatch in the x-axis, data points, mean lines, etc.)
# and that makes sense - two dolls in one room, one doll was on 'easy' mode and the other was on 'demanding' mode. 
# The participants did have access to their personal materials. 
# With David's initial code - these data were combined (total % of intervals with care, not separated by doll).
# Is there some benefit of showing that, too? Hm. 

# For next time: Figure out the x-axis mismatch, gray scale, other visualizations (S-S, bars)?
